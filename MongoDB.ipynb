# %%
# !pip install pymongo
from pymongo import MongoClient
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 22.5 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

client = MongoClient(
    "mongodb+srv://sandunalsha72_db_user:SandunMadusanka%40321@cluster0.kt0hmtd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
)

db = client["northstar"]

complaints_collection = db["complaints"]

# %%
complaints_collection.insert_one({
    "complaint_id": "CP0001",
    "customer_id": "C0046",
    "complaint_type": "Delay",
    "severity": "High",
    "status": "Open"
})
# Out:
# InsertOneResult(ObjectId('6a0351f93a3d4024060402da'), acknowledged=True)

# %%
complaints_collection.find_one({"complaint_id": "CP0001"})
# Out:
# {'_id': ObjectId('69fcde04fd3ef814342c38a9'),
#  'complaint_id': 'CP0001',
#  'customer_id': 'C0046',
#  'complaint_type': 'Delay',
#  'severity': 'High',
#  'status': 'Open'}

# %%
complaints_collection.create_index("complaint_id")
# Out:
# 'complaint_id_1'

# %%
db.list_collection_names()
# Out:
# ['vehicles', 'incidents', 'deliveries', 'complaints', 'drivers']

# %%
complaints_collection.find_one({"complaint_id": "CP0001"})
# Out:
# {'_id': ObjectId('69fcde04fd3ef814342c38a9'),
#  'complaint_id': 'CP0001',
#  'customer_id': 'C0046',
#  'complaint_type': 'Delay',
#  'severity': 'High',
#  'status': 'Open'}

# %%
complaints_collection.create_index("complaint_id")
# Out:
# 'complaint_id_1'

# %%
complaints_collection.find(
    {"complaint_id": "CP0001"}
).explain()
# Out:
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'northstar.complaints',
#   'parsedQuery': {'complaint_id': {'$eq': 'CP0001'}},
#   'indexFilterSet': False,
#   'queryHash': '3754CB4F',
#   'planCacheShapeHash': '3754CB4F',
#   'planCacheKey': '6F8095AA',
#   'optimizationTimeMillis': 0,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'stage': 'FETCH',
#    'inputStage': {'stage': 'IXSCAN',
#     'keyPattern': {'complaint_id': 1},
#     'indexName': 'complaint_id_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'complaint_id': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'complaint_id': ['["CP0001", "CP0001"]']}}},
#   'rejectedPlans': []},
#  'executionStats': {'executionSuccess': True,
# ...

# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 27.2 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

client = MongoClient(
    "mongodb+srv://sandunalsha72_db_user:SandunMadusanka%40321@cluster0.kt0hmtd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
)

db = client["northstar"]

db.list_collection_names()
# Out:
# ['vehicles', 'incidents', 'deliveries', 'complaints', 'drivers']

# %%
vehicles_collection = db["vehicles"]

vehicles_collection.insert_one({
    "vehicle_id": "V002",
    "vehicle_type": "Truck",
    "assigned_zone": "South",
    "battery_health_pct": 88.5
})
# Out:
# InsertOneResult(ObjectId('6a0468455458fea0e9920dd7'), acknowledged=True)

# %%
pipeline = [
    {"$group": {"_id": "$assigned_zone", "total_vehicles": {"$sum": 1}}}
]

list(vehicles_collection.aggregate(pipeline))
# Out:
# [{'_id': 'North', 'total_vehicles': 1}, {'_id': 'South', 'total_vehicles': 1}]

# %%
complaints_collection.find(
    {"complaint_id": "CP0001"}
).explain()
# Out:
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'northstar.complaints',
#   'parsedQuery': {'complaint_id': {'$eq': 'CP0001'}},
#   'indexFilterSet': False,
#   'queryHash': '3754CB4F',
#   'planCacheShapeHash': '3754CB4F',
#   'planCacheKey': '6F8095AA',
#   'optimizationTimeMillis': 0,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'stage': 'FETCH',
#    'inputStage': {'stage': 'IXSCAN',
#     'keyPattern': {'complaint_id': 1},
#     'indexName': 'complaint_id_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'complaint_id': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'complaint_id': ['["CP0001", "CP0001"]']}}},
#   'rejectedPlans': []},
#  'executionStats': {'executionSuccess': True,
# ...

# %%
from scipy.stats import ttest_ind

group1 = [202, 132, 180, 210]
group2 = [616, 590, 630, 610]

t_stat, p_value = ttest_ind(group1, group2)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: -22.203802989881666
# P-value: 5.456912264147062e-07
